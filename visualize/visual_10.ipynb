# %%
import numpy as np
from matplotlib import pyplot as plt
import json

# %%
with open('./benchmark/synthetic/data/synthetic(0.0,0.0)10.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
X = np.array([len(client['train_set']['y']) for client in data['clients']])
X = X / X.sum()
X
# Out:
# array([0.246     , 0.154     , 0.11566667, 0.09333333, 0.084     ,
#        0.07366667, 0.072     , 0.05766667, 0.055     , 0.04866667])

# %%
Y = np.array([30.22363889, 30.41994445, 31.04711111, 32.20925, 31.54277778, 32.13377778
, 26.76927778, 32.08361111, 31.79252777, 27.94475001])
Y = Y / Y.sum()
Y
# Out:
# array([0.09871629, 0.09935747, 0.10140592, 0.10520169, 0.10302486,
#        0.10495518, 0.08743368, 0.10479133, 0.10384059, 0.091273  ])

# %%
Z = np.array([16.83037818, 16.58932314, 17.49897105, 18.12931791, 16.30941053, 16.80589166
, 11.88834869, 14.76737441, 14.89358522, 12.52580801])
Z = Z / Z.sum()
Z
# Out:
# array([0.10772241, 0.10617954, 0.11200172, 0.11603624, 0.10438797,
#        0.10756569, 0.07609108, 0.09451821, 0.09532602, 0.08017112])

# %%
T = np.array([0.788333334128062, 0.7916666674613952, 0.7916666666666666, 0.7983333325386047, 0.793333334128062, 0.7949999992052714, 0.7466666674613953, 0.79, 0.7916666658719381, 0.7549999992052714])
T = T / T.sum()
T
# Out:
# array([0.10053135, 0.10095643, 0.10095643, 0.10180659, 0.10116897,
#        0.10138151, 0.09521785, 0.10074389, 0.10095643, 0.09628055])

# %%
W = np.array([16.41632275, 15.43599735, 16.43410582, 17.27929828, 15.43571429, 16.10025331
, 12.98982077, 15.76303637, 15.45582209, 13.7729623])
W = W / W.sum()
W
# Out:
# array([0.10585485, 0.09953357, 0.10596952, 0.11141944, 0.09953174,
#        0.10381679, 0.08376026, 0.10164236, 0.0996614 , 0.08881007])

# %%
U = np.array([15.99409862, 16.09887602, 16.46910963, 17.09912285, 15.94287653, 16.68009927, 13.29312366, 16.0294239, 15.73558218, 13.92487115])
U = U / U.sum()
U
# Out:
# array([0.10170017, 0.1023664 , 0.10472057, 0.10872658, 0.10137446,
#        0.10606217, 0.08452573, 0.10192479, 0.10005636, 0.08854276])

# %%
plt.figure(figsize=(12, 8))
# plt.plot(X, label='data')
plt.plot(W, label='exact')
plt.plot(Y, label='const lambda')
# plt.plot(Z, label='optimal lambda (n_samples=30)')
plt.plot(U, label='optimal lambda (n_samples=300)')
# plt.plot(T, label='global test accuracy on local models')
plt.legend()
plt.show()
# Non IID
