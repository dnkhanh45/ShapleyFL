# %%
import numpy as np
from matplotlib import pyplot as plt
import json

# %%
with open('./benchmark/synthetic/data/synthetic(0.0,0.0).json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
X = np.array([len(client['train_set']['y']) for client in data['clients']])
X = X / X.sum()
X
# Out:
# array([0.1975    , 0.12333333, 0.09208333, 0.074375  , 0.066875  ,
#        0.05854167, 0.05708333, 0.04708333, 0.04229167, 0.035     ,
#        0.03833333, 0.036875  , 0.03791667, 0.03333333, 0.03229167,
#        0.02708333])

# %%
Y = np.array([8.73056237, 9.3187547, 10.46699256, 10.6821892, 9.55462538, 9.24019046
, 10.65984603, 7.85608161, 9.87349313, 8.64741756, 8.75116206, 8.5561502
, 9.72933449, 7.61389588, 8.81054675, 9.51436053])
Y = Y / Y.sum()
Y
# Out:
# array([0.05898805, 0.06296218, 0.07072025, 0.07217422, 0.06455584,
#        0.06243136, 0.07202326, 0.05307962, 0.06671027, 0.05842629,
#        0.05912723, 0.05780964, 0.06573626, 0.05144329, 0.05952847,
#        0.06428379])

# %%
Z = np.array([0.7552083333333334, 0.7677083333333333, 0.7677083333333333, 0.771875, 0.7729166666666667, 0.7635416666666667, 0.7645833333333333, 0.7583333333333333, 0.7729166666666667, 0.765625, 0.7677083333333333, 0.7583333333333333, 0.7729166666666667, 0.7645833333333333, 0.7666666666666667, 0.765625])
Z = Z / Z.sum()
Z
# Out:
# array([0.06161822, 0.06263811, 0.06263811, 0.06297807, 0.06306306,
#        0.06229815, 0.06238314, 0.06187319, 0.06306306, 0.06246813,
#        0.06263811, 0.06187319, 0.06306306, 0.06238314, 0.06255312,
#        0.06246813])

# %%
plt.figure(figsize=(12, 8))
plt.plot(X, label='data')
plt.plot(Y, label='optimal lambda')
plt.plot(Z, label='global test accuracy on local model')
plt.legend()
plt.show()
